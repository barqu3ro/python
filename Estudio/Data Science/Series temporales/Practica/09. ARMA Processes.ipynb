# %% [markdown]
# # Procesos ARMA
#
# Son los procesos estacionarios que contienen componentes autorregresivos como de media móviles.

# %%
import warnings
warnings.filterwarnings(action="ignore")

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import pandas as pd
# %matplotlib inline

from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARIMA

from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# ### Simulamos un proceso ARMA con orden p=1 y q=1

# %%
# Simulamos un proceso ARMA de orden p=1 y q=1
ar1 = np.array([1, 0.3])
ma1 = np.array([1, 0.6])
p = len(ar1)-1
q = len(ma1)-1
N_SAMPLES = 1000

simulated_ARMA11 = ArmaProcess(ar=ar1, ma=ma1).generate_sample(nsample=N_SAMPLES)

# Simulamos un proceso ARMA de orden p=1 y q=1
plt.figure(figsize=[10, 6])
plt.plot(simulated_ARMA11)
plt.title("Simulated ARMA(1,1) Process")
plt.show()

# %%
# Visualizamos las autocorrelaciones
fig, ax = plt.subplots(1,2,figsize=(10,5))
plot_acf(simulated_ARMA11, lags=20, ax=ax[0])
plot_pacf(simulated_ARMA11, lags=20, ax=ax[1])
plt.show()

# %%
# Entrenamos el modelo
model = ARIMA(simulated_ARMA11, order=(p, 0, q))
results_ARMA11 = model.fit(disp=-1)

# Visualizamos las predicciones vs la serie original
plt.figure(figsize=[10, 6])
plt.plot(simulated_ARMA11)
plt.plot(results_ARMA11.fittedvalues, '-r')

# Métrica
rmse = sqrt(mean_squared_error(simulated_ARMA11, results_ARMA11.fittedvalues))
print("RMSE:", np.round(rmse, 3))
# Out:
# RMSE: 1.004

# %% [markdown]
# ### Simulamos un proceso ARMA con orden p=2 y q=1

# %%
# Simulamos un proceso ARMA de orden p=2 y q=1
ar2 = np.array([1, 0.3, 0.5])
ma1 = np.array([1, 0.6])
p = len(ar2)-1
q = len(ma1)-1
N_SAMPLES = 1000

simulated_ARMA21 = ArmaProcess(ar=ar2, ma=ma1).generate_sample(nsample=N_SAMPLES)

# Simulamos un proceso ARMA de orden p=2 y q=1
plt.figure(figsize=[10, 6])
plt.plot(simulated_ARMA21)
plt.title("Simulated ARMA(2,1) Process")
plt.show()

# %%
# Visualizamos las autocorrelaciones
fig, ax = plt.subplots(1,2,figsize=(10,5))
plot_acf(simulated_ARMA21, lags=20, ax=ax[0])
plot_pacf(simulated_ARMA21, lags=20, ax=ax[1])
plt.show()

# %%
# Entrenamos el modelo
model = ARIMA(simulated_ARMA21, order=(p, 0, q))
results_ARMA21 = model.fit(disp=-1)

# Visualizamos las predicciones vs la serie original
plt.figure(figsize=[10, 6])
plt.plot(simulated_ARMA21)
plt.plot(results_ARMA21.fittedvalues, '-r')

# Métrica
rmse = sqrt(mean_squared_error(simulated_ARMA21, results_ARMA21.fittedvalues))
print("RMSE:", np.round(rmse, 3))
# Out:
# RMSE: 1.001

# %% [markdown]
# ### Simulamos un proceso ARMA con orden p=1 y q=2

# %%
# Simulamos un proceso ARMA de orden p=1 y q=2
ar1 = np.array([1, 0.3])
ma2 = np.array([1, 0.6, 0.2])
p = len(ar1)-1
q = len(ma2)-1
N_SAMPLES = 1000

simulated_ARMA12 = ArmaProcess(ar=ar1, ma=ma2).generate_sample(nsample=N_SAMPLES)

# Simulamos un proceso ARMA de orden p=1 y q=2
plt.figure(figsize=[10, 6])
plt.plot(simulated_ARMA12)
plt.title("Simulated ARMA(1,2) Process")
plt.show()

# %%
# Visualizamos las autocorrelaciones
fig, ax = plt.subplots(1,2,figsize=(10,5))
plot_acf(simulated_ARMA12, lags=20, ax=ax[0])
plot_pacf(simulated_ARMA12, lags=20, ax=ax[1])
plt.show()

# %%
# Entrenamos el modelo
model = ARIMA(simulated_ARMA12, order=(p, 0, q))
results_ARMA12 = model.fit(disp=-1)

# Visualizamos las predicciones vs la serie original
plt.figure(figsize=[10, 6])
plt.plot(simulated_ARMA12)
plt.plot(results_ARMA12.fittedvalues, '-r')

# Métrica
rmse = sqrt(mean_squared_error(simulated_ARMA12, results_ARMA12.fittedvalues))
print("RMSE:", np.round(rmse, 3))
# Out:
# RMSE: 0.972

# %% [markdown]
# ### Simulamos un proceso ARMA con orden p=2 y q=2

# %%
# Simulamos un proceso ARMA de orden p=2 y q=2
ar2 = np.array([1, 0.3, 0.5])
ma2 = np.array([1, 0.6, 0.2])
p = len(ar2)-1
q = len(ma2)-1
N_SAMPLES = 1000

simulated_ARMA22 = ArmaProcess(ar=ar2, ma=ma2).generate_sample(nsample=N_SAMPLES)

# Simulamos un proceso ARMA de orden p=2 y q=2
plt.figure(figsize=[10, 6])
plt.plot(simulated_ARMA22)
plt.title("Simulated ARMA(2,2) Process")
plt.show()

# %%
# Visualizamos las autocorrelaciones
fig, ax = plt.subplots(1,2,figsize=(10,5))
plot_acf(simulated_ARMA22, lags=20, ax=ax[0])
plot_pacf(simulated_ARMA22, lags=20, ax=ax[1])
plt.show()

# %%
# Entrenamos el modelo
model = ARIMA(simulated_ARMA22, order=(p, 0, q))
results_ARMA22 = model.fit(disp=-1)

# Visualizamos las predicciones vs la serie original
plt.figure(figsize=[10, 6])
plt.plot(simulated_ARMA22)
plt.plot(results_ARMA22.fittedvalues, '-r')

# Métrica
rmse = sqrt(mean_squared_error(simulated_ARMA22, results_ARMA22.fittedvalues))
print("RMSE:", np.round(rmse, 3))
# Out:
# RMSE: 1.0

# %% [markdown]
# ### Air Passengers Dataset

# %%
# Cargamos el dataset
real = pd.read_csv('data/AirPassengers.csv', header = 0, parse_dates = [0], names = ['Month', 'Passengers'], index_col = 0)

ax = real.plot(figsize=(18,6), title='Pasajeros de Avión');
ax.set_xlabel("Años");
ax.set_ylabel("# Pasajeros");

# %%
def splitSet(df, TEST_SIZE):
    
    # Train set
    train_full = df[:(int(len(df)*(1-TEST_SIZE)))]
    train = train_full[:(int(len(train_full)*(1-TEST_SIZE)))]

    # Validation set
    valid = train_full[(int(len(train_full)*(1-TEST_SIZE))):]

    # Test set
    test = df[(int(len(df)*(1-TEST_SIZE))):]

    return train, valid, test

# %%
TEST_SIZE = 0.24
train, valid, test = splitSet(real, TEST_SIZE)

# Trabajamos sólo con train y test
train = pd.concat([train, valid], axis=0)

# Visualización
ax = real.plot(figsize=(18,6), title='Pasajeros de avión');

init__limit = real.index[0]
train_limit = real.index[len(train)-1]
test__limit = real.index[len(train)+len(test)-1]

ax.axvline(train_limit, linestyle='--', color='blue')
ax.axvline(test__limit, linestyle='--', color='red')

ax.axvspan(init__limit, train_limit, alpha=0.1, color='blue')
ax.axvspan(train_limit, test__limit, alpha=0.1, color='red')

ax.text(real.index[int((len(train)-1)*0.5)], 610, 'Train set', fontsize=18)
ax.text(real.index[int(len(train)+(len(test)-1)*0.3)], 610, 'Test set', fontsize=18)

ax.grid(linestyle='--')

ax.set_xlabel("Fecha");
ax.set_ylabel("Pasajeros");

# %%
# Model
MODEL = 'ARMA Process'

# Coefficients
p=2
q=1

# Training model
model = ARIMA(train, order=(p, 0, q))
fitted_model = model.fit(disp=-1)
fitted_train = fitted_model.fittedvalues

# Get Test Set Predictions
predict_test = fitted_model.predict(test.index[0], test.index[len(test)-1])

# Get RMSE from Test Set
real_values = test['Passengers']
pred_values = predict_test
rmse = sqrt(mean_squared_error(real_values, pred_values))

# Get predictions from whole set
predictions = fitted_model.predict(real.index[0], real.index[len(real)-1])

# Preparing data to plot
real_plot = real['Passengers']
pred_plot = predictions

# Visualization
figure(figsize=(18, 6))

real_plot.plot(label='Real Value')
pred_plot.plot(label='Predictions', color='red')
plt.suptitle(MODEL + ' - RMSE: ' + str(np.round(rmse, 3)), fontsize=20)
plt.legend();

plt.axvline(train_limit, linestyle='--', color='blue');
plt.axvline(test__limit, linestyle='--', color='red');

plt.axvspan(init__limit, train_limit, alpha=0.1, color='blue');
plt.axvspan(train_limit, test__limit, alpha=0.1, color='red');

plt.grid(linestyle='--')
# Out:
# C:\Users\eduar\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %% [markdown]
# ¿Qué nos ocurre ahora? Si tenemos un proceso estadístico que debería modelar muy bien las series temporales...
